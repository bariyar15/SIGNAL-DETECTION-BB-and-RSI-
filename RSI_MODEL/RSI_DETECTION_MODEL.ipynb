# %%
pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="rfWGXO9nBOb7wgjg5YO9aA")
project = rf.workspace().project("rsi_indicator")
model = project.version(1).model

# infer on a local image
print(model.predict("/content/drive/MyDrive/RSI_MODEL/RSI_IMAGES_for_testing/ADANIENT.NS_2002_RSI.png", confidence=40, overlap=30).json())

# visualize your prediction
model.predict("/content/drive/MyDrive/RSI_MODEL/RSI_IMAGES_for_testing/ADANIENT.NS_2002_RSI.png", confidence=40, overlap=30).save("prediction.jpg")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-ee6b4f3d4e3a> in <cell line: 2>()
#       1 from roboflow import Roboflow
# ----> 2 rf = Roboflow(api_key="rfWGXO9nBOb7wgjg5YO9aA")
#       3 project = rf.workspace().project("rsi_indicator")
#       4 model = project.version(1).model
#       5
#
# /usr/local/lib/python3.10/dist-packages/roboflow/__init__.py in __init__(self, api_key, model_format, notebook)
#     215         self.notebook = notebook
#     216         self.onboarding = False
# --> 217         self.auth()
#     218
#     219     def auth(self):
#
# /usr/local/lib/python3.10/dist-packages/roboflow/__init__.py in auth(self)
#     218
#     219     def auth(self):
# --> 220         r = check_key(self.api_key, self.model_format, self.notebook)
#     221
#     222         if r == "onboarding":
#
# ...
