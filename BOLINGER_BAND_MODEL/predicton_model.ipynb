# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Lvkw8J4A5B68Mk3KSyUt")
project = rf.workspace().project("signal_detect")
model = project.version(3).model

# infer on a local image
#you can add images
print(model.predict("/content/drive/MyDrive/project_work(BB and RSI)/BOLINGER_BAND_MODEL/image_2.png", confidence=40, overlap=30).json())

model.predict("/content/drive/MyDrive/project_work(BB and RSI)/BOLINGER_BAND_MODEL/image_2.png", confidence=40, overlap=30).save("prediction_new.jpg")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
